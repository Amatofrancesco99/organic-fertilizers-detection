# %%
# Import useful libraries
import pandas as pd, numpy as np, json, pydeck as pdk, pickle, seaborn as sns, utils, matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# # **Generalization (I)**
#
# The project aim is to create a Machine Learning model capable of detecting the dates when a crop field has been manured, using satellite data. <br>
# Now is the turn to see how much the *best model*, obtained in the [ML models notebook](../3-ml-models/notebook.ipynb), can generalize our classification problem. More precisely, the purpose is to see how it performs in detecting when crop fields have been manured in a different country from the trained one.
#
# **N.B:** Since using radar indexes is useless (as seen), they won't be considered. <br>
# The dataset used to test generalization contains features that have been extracted using the [features-extraction notebook](../1-features-extraction/notebook.ipynb) (all crop fields details can be found in the [other-fields JSON file](../../Datasets/other/other-fields.json)).

# %%
s2_df =  pd.read_csv('../../Datasets/other/other-fields-s2-features-extracted.gz', compression='gzip')

# %% [markdown]
# ## **Show crop fields locations on Earth-map**
#
# The objective is just visualizing where our crops, used to test the generalization capability of the final obtained model, are geographically located. This can provide several benefits, including:
# * **Spatial context:** it can provide a spatial context that makes it easier to understand the geographic distribution of the fields. This can be especially useful for people who are not familiar with the area or the crops being considered
# * **Data exploration:** it can make it easier to explore the data contained in the JSON file. Users can zoom in and out, pan, and filter the data to focus on specific areas or types of crops
# * **Data validation:** it can help validate the data contained in the JSON file. Users can visually confirm that the crop fields are located in the correct locations, and identify any potential errors or discrepancies in the data
# * **Communication:** it can be a powerful way to communicate data to others. Users can share the map with stakeholders or the public to help them understand the geographic distribution of crop fields

# %%
# Load JSON data from file
with open('../../Datasets/other/other-fields.json') as f:
    data = json.load(f)

# Create DataFrame with properties excluding 'manure_dates' column
fields_df = pd.DataFrame([{k:v for k,v in f['properties'].items() if k!='manure_dates'} for f in data['features']])

# Add column with coordinates for each field
fields_df['polygon_coordinates'] = [[tuple(c) for c in p] for f in data['features'] for p in f['geometry']['coordinates']]

layer = pdk.Layer(
    'PolygonLayer',
    data=fields_df,
    get_polygon='polygon_coordinates',
    get_fill_color=[255, 255, 0, 100],
    get_line_color=[255, 255, 0, 100],
    stroked=True,
    filled=True,
    lineWidthMinPixels=3,
    pickable=True,
    auto_highlight=True,
)

# Define the initial view state of the map
view_state = pdk.ViewState(
    longitude=fields_df.polygon_coordinates[0][1][0],
    latitude=fields_df.polygon_coordinates[0][1][1] + 0.3,
    zoom=8
)

# Create the map with the layers and the initial view state
r = pdk.Deck(layers=layer, initial_view_state=view_state,)

# Show the map
r
# Out:
# {
#   "initialViewState": {
#     "latitude": 45.55201727136672,
#     "longitude": 9.018329621443346,
#     "zoom": 8
#   },
#   "layers": [
#     {
#       "@@type": "PolygonLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "crop_field_name": "P-PVPR1",
#           "polygon_coordinates": [
#             [
#               9.017948747763231,
#               45.25186621136
#             ],
#             [
#               9.018329621443346,
#               45.252017271366725
#             ],
#             [
#               9.01924157250841,
#               45.252587519270854
#             ],
#             [
#               9.017782450804308,
#               45.253346582100804
#             ],
#             [
#               9.016945601591662,
#               45.252549754686044
#             ],
#             [
#               9.017948747763231,
#               45.25186621136
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR2",
#           "polygon_coordinates": [
#             [
#               9.019343496450976,
#               45.25260640155387
#             ],
#             [
#               9.019890667090014,
#               45.25290851722802
#             ],
#             [
#               9.018050671705797,
#               45.25361848273611
#             ],
#             [
#               9.017862917074755,
#               45.25341455738167
#             ],
#             [
#               9.019343496450976,
#               45.25260640155387
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR3",
#           "polygon_coordinates": [
#             [
#               9.020040870794848,
#               45.25299537518688
#             ],
#             [
#               9.021027923712328,
#               45.254354873752824
#             ],
#             [
#               9.020314456114367,
#               45.25462676956063
#             ],
#             [
#               9.01924693692644,
#               45.253308818020734
#             ],
#             [
#               9.020040870794848,
#               45.25299537518688
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR4",
#           "polygon_coordinates": [
#             [
#               9.018090180225053,
#               45.25374221542734
#             ],
#             [
#               9.019141606158891,
#               45.25334947050309
#             ],
#             [
#               9.020209125346819,
#               45.254637210540146
#             ],
#             [
#               9.019216708011308,
#               45.255022393968694
#             ],
#             [
#               9.018090180225053,
#               45.25374221542734
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR5",
#           "polygon_coordinates": [
#             [
#               9.019055775470415,
#               45.25509036724367
#             ],
#             [
#               9.017639569110552,
#               45.25567946555221
#             ],
#             [
#               9.017451814479509,
#               45.255475547598515
#             ],
#             [
#               9.017516187495866,
#               45.255373588347084
#             ],
#             [
#               9.016775897807756,
#               45.254637210540146
#             ],
#             [
#               9.0166578806111,
#               45.25428978795189
#             ],
#             [
#               9.01792388326613,
#               45.25376865008428
#             ],
#             [
#               9.019055775470415,
#               45.25509036724367
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR6",
#           "polygon_coordinates": [
#             [
#               9.01590379704571,
#               45.25701673111443
#             ],
#             [
#               9.01787790288067,
#               45.25963732755059
#             ],
#             [
#               9.01636513699627,
#               45.26000737320981
#             ],
#             [
#               9.014551963702203,
#               45.25757560044289
#             ],
#             [
#               9.01590379704571,
#               45.25701673111443
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPR7",
#           "polygon_coordinates": [
#             [
#               9.017598953143121,
#               45.25639743705563
#             ],
#             [
#               9.019733991518976,
#               45.25929748757586
#             ],
#             [
#               9.019315566912653,
#               45.25969774333317
#             ],
#             [
#               9.018178310290338,
#               45.259576911703746
#             ],
#             [
#               9.016204204455377,
#               45.256926103137445
#             ],
#             [
#               9.017598953143121,
#               45.25639743705563
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR1",
#           "polygon_coordinates": [
#             [
#               8.298501673061258,
#               45.543279412975494
#             ],
#             [
#               8.301977815944559,
#               45.543497323138205
#             ],
#             [
#               8.301849069911844,
#               45.544278787120625
#             ],
#             [
#               8.29845875771702,
#               45.5440834221434
#             ],
#             [
#               8.298501673061258,
#               45.543279412975494
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR2",
#           "polygon_coordinates": [
#             [
#               8.298630419093973,
#               45.54231759251069
#             ],
#             [
#               8.302106561977274,
#               45.542527992143434
#             ],
#             [
#               8.302042188960916,
#               45.54339212523408
#             ],
#             [
#               8.298544588405496,
#               45.54320427134422
#             ],
#             [
#               8.298630419093973,
#               45.54231759251069
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR3",
#           "polygon_coordinates": [
#             [
#               8.29871624978245,
#               45.54111529379002
#             ],
#             [
#               8.302235308009989,
#               45.54135575559102
#             ],
#             [
#               8.302095833141214,
#               45.54241527815241
#             ],
#             [
#               8.298651876766092,
#               45.542212392399065
#             ],
#             [
#               8.29871624978245,
#               45.54111529379002
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR4",
#           "polygon_coordinates": [
#             [
#               8.298823538143045,
#               45.53990545475003
#             ],
#             [
#               8.302374782878763,
#               45.54011586340964
#             ],
#             [
#               8.302224579173929,
#               45.541235524819065
#             ],
#             [
#               8.298737707454569,
#               45.541040149266315
#             ],
#             [
#               8.298823538143045,
#               45.53990545475003
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR5",
#           "polygon_coordinates": [
#             [
#               8.298872676017414,
#               45.53923433238597
#             ],
#             [
#               8.300111856582294,
#               45.5389149567824
#             ],
#             [
#               8.302509751441608,
#               45.539076523490934
#             ],
#             [
#               8.302397098662983,
#               45.54002712751405
#             ],
#             [
#               8.298835125091205,
#               45.53982799045259
#             ],
#             [
#               8.298872676017414,
#               45.53923433238597
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR6",
#           "polygon_coordinates": [
#             [
#               8.29705660653174,
#               45.54232783141596
#             ],
#             [
#               8.298360160112978,
#               45.54241048849336
#             ],
#             [
#               8.298183134317995,
#               45.54407111857473
#             ],
#             [
#               8.296938589335085,
#               45.54402227721365
#             ],
#             [
#               8.29705660653174,
#               45.54232783141596
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR7",
#           "polygon_coordinates": [
#             [
#               8.297147706908582,
#               45.541578552036505
#             ],
#             [
#               8.297244266433118,
#               45.540830256758085
#             ],
#             [
#               8.297330097121595,
#               45.54014643442406
#             ],
#             [
#               8.297410563392042,
#               45.5396918006872
#             ],
#             [
#               8.297512487334608,
#               45.539590352988064
#             ],
#             [
#               8.298596099776624,
#               45.53930855286339
#             ],
#             [
#               8.298305475621563,
#               45.54228693996528
#             ],
#             [
#               8.297087752728801,
#               45.54221931130782
#             ],
#             [
#               8.297147706908582,
#               45.541578552036505
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR8",
#           "polygon_coordinates": [
#             [
#               8.278721534555897,
#               45.54697530626797
#             ],
#             [
#               8.280191385096058,
#               45.54711806570465
#             ],
#             [
#               8.27965494329308,
#               45.54984545267831
#             ],
#             [
#               8.27815290624474,
#               45.54969518686838
#             ],
#             [
#               8.278721534555897,
#               45.54697530626797
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-BIPR9",
#           "polygon_coordinates": [
#             [
#               8.277701010624575,
#               45.546285377001695
#             ],
#             [
#               8.278678002643263,
#               45.54578610430237
#             ],
#             [
#               8.278804066466963,
#               45.54582649108681
#             ],
#             [
#               8.278010257682217,
#               45.54959907680697
#             ],
#             [
#               8.277886876067532,
#               45.549670453238825
#             ],
#             [
#               8.277015649622426,
#               45.54958248724731
#             ],
#             [
#               8.277701010624575,
#               45.546285377001695
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-VAPR1",
#           "polygon_coordinates": [
#             [
#               8.798287971969993,
#               45.79133346681193
#             ],
#             [
#               8.798290654179008,
#               45.79125491695544
#             ],
#             [
#               8.798438175674827,
#               45.79110371552986
#             ],
#             [
#               8.79861520146981,
#               45.790899858880465
#             ],
#             [
#               8.79870907878533,
#               45.79080821665754
#             ],
#             [
#               8.798768087383658,
#               45.790778292633746
#             ],
#             [
#               8.798821731563956,
#               45.7907670711207
#             ],
#             [
#               8.798911585565955,
#               45.79078109801165
#             ],
#             [
#               8.799067153688819,
#               45.79083720554024
#             ],
#             [
#               8.7990819058384,
#               45.790869934905885
#             ],
#             [
#               8.799052401539237,
#               45.79093913407277
#             ],
#             [
#               8.798974617477805,
#               45.791027035593274
#             ],
#             [
#               8.798899515625388,
#               45.79109062384085
#             ],
#             [
#               8.798864646908195,
#               45.7911298988987
#             ],
#             [
#               8.798799861005433,
#               45.791195357266915
#             ],
#             [
#               8.798756945661195,
#               45.79125707508655
#             ],
#             [
#               8.79873280578006,
#               45.791318792837856
#             ],
#             [
#               8.798751581243165,
#               45.791389861678944
#             ],
#             [
#               8.798722076944001,
#               45.79145344951257
#             ],
#             [
#               8.79860674195636,
#               45.791500205226306
#             ],
#             [
#               8.798472631505616,
#               45.791464670887436
#             ],
#             [
#               8.798362660936005,
#               45.79139921283551
#             ],
#             [
#               8.798287971969993,
#               45.79133346681193
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-VAPR2",
#           "polygon_coordinates": [
#             [
#               8.658803437240303,
#               45.85842753378426
#             ],
#             [
#               8.659361336715401,
#               45.858760033348474
#             ],
#             [
#               8.65914675999421,
#               45.85884595987881
#             ],
#             [
#               8.659066293834075,
#               45.85893375417656
#             ],
#             [
#               8.659018013961495,
#               45.85903649214644
#             ],
#             [
#               8.658929501236464,
#               45.85910373860183
#             ],
#             [
#               8.658808801658333,
#               45.85923823148284
#             ],
#             [
#               8.658572767265023,
#               45.85933536497635
#             ],
#             [
#               8.658411834724129,
#               45.859275590538886
#             ],
#             [
#               8.65825358439225,
#               45.85939700729767
#             ],
#             [
#               8.658241514680979,
#               45.859448375798564
#             ],
#             [
#               8.65814897824067,
#               45.85969401025168
#             ],
#             [
#               8.657719824798287,
#               45.859436234193865
#             ],
#             [
#               8.657998774535836,
#               45.8592083442199
#             ],
#             [
#               8.658191893584908,
#               45.85896924553828
#             ],
#             [
#               8.658503029830635,
#               45.858730145828524
#             ],
#             [
#               8.658701513297737,
#               45.85861806748562
#             ],
#             [
#               8.658701513297737,
#               45.85853587655726
#             ],
#             [
#               8.658803437240303,
#               45.85842753378426
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVPE",
#           "polygon_coordinates": [
#             [
#               9.214185584391105,
#               45.16393844291401
#             ],
#             [
#               9.214131940210807,
#               45.16389305472647
#             ],
#             [
#               9.214373339022147,
#               45.16344941578047
#             ],
#             [
#               9.214607192157445,
#               45.16295433763365
#             ],
#             [
#               9.214897400628338,
#               45.162368698733864
#             ],
#             [
#               9.215210556458686,
#               45.16170238544692
#             ],
#             [
#               9.215578019093726,
#               45.161755340365055
#             ],
#             [
#               9.215610205601905,
#               45.16174777537977
#             ],
#             [
#               9.215942799519752,
#               45.16036336615981
#             ],
#             [
#               9.217133700322364,
#               45.16047684359105
#             ],
#             [
#               9.216811835240577,
#               45.16116526849583
#             ],
#             [
#               9.216554343175147,
#               45.16165699547791
#             ],
#             [
#               9.21624320692942,
#               45.16231514648918
#             ],
#             [
#               9.215856968831275,
#               45.163003549181674
#             ],
#             [
#               9.21550291724131,
#               45.16355577829575
#             ],
#             [
#               9.21522396750376,
#               45.163947035824876
#             ],
#             [
#               9.214837729405616,
#               45.164332833900644
#             ],
#             [
#               9.214118897389625,
#               45.164060506118375
#             ],
#             [
#               9.214185584391105,
#               45.16393844291401
#             ]
#           ]
#         },
#         {
#           "crop_field_name": "P-PVTG",
#           "polygon_coordinates": [
#             [
#               9.153547945574303,
#               45.21045332963058
#             ],
#             [
#               9.155687058846793,
#               45.20984884578032
#             ],
#             [
#               9.15536619185592,
#               45.208355190546044
#             ],
#             [
#               9.153952000303551,
#               45.20859967043266
#             ],
#             [
#               9.153020297633756,
#               45.208891035500464
#             ],
#             [
#               9.153547945574303,
#               45.21045332963058
#             ]
#           ]
#         }
#       ],
#       "filled": true,
#       "getFillColor": [
#         255,
#         255,
#         0,
#         100
#       ],
#       "getLineColor": [
#         255,
#         255,
#         0,
#         100
#       ],
#       "getPolygon": "@@=polygon_coordinates",
#       "id": "ed423c4b-0b2e-41dc-9dec-683f8e629f2f",
#       "lineWidthMinPixels": 3,
#       "pickable": true,
#       "stroked": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %% [markdown]
# ## **Modify original DataFrame**
#
# The purpose of building this `DataFrame`, and modifying the [original one](../../Datasets/other/other-fields-s2-features-extracted.gz), is to ensure that its data structure will be compliant with the one used to train the Machine Learning model.
#
# By doing so, it can be ensured that the data is consistent and that the model can make predictions. This will help to check whether the research objectives have been achieved and ensure that the model is optimized for the classification task at hand.

# %%
# Sentinel-2
s2_df_mod = utils.get_modified_df(s2_df, sentinel=2)
s2_df_mod
# Out:
#     crop_field_name consequent_s2_acquisitions          B1          B2  \
# 0           P-BIPR1   [2022-02-20, 2022-02-23] -389.431116 -339.716746
# 1           P-BIPR1   [2022-02-23, 2022-02-25]  214.302257  278.160926
# 2           P-BIPR1   [2022-02-25, 2022-02-28] -189.252969 -192.158551
# 3           P-BIPR1   [2022-02-28, 2022-03-02]  123.960808   57.005344
# 4           P-BIPR1   [2022-03-02, 2022-03-07]  -76.965558   15.435867
# ..              ...                        ...         ...         ...
# 240         P-VAPR2   [2022-04-14, 2022-04-16]   -9.732584   21.604494
# 241         P-VAPR2   [2022-04-16, 2022-04-19]  -20.541573  -33.973034
# 242         P-VAPR2   [2022-04-19, 2022-05-01]  102.921348  -33.885393
# 243         P-VAPR2   [2022-05-01, 2022-05-11]   69.453933   45.494382
# 244         P-VAPR2   [2022-05-11, 2022-05-14]  -47.294382  -54.748315
#
#              B3          B4          B5          B6          B7          B8  \
# 0   -255.979810 -204.013658 -220.684679 -153.935273 -131.498219  -97.479216
# 1    206.995249  146.890736  143.897862  145.757126  158.265439  176.870546
# 2   -163.187055 -134.046912 -153.233373 -120.970309 -132.595012  -98.599762
# 3    130.099169  132.657363  214.154394  303.942993  322.084917  322.342637
# 4    -41.457838  -41.994062  -47.529097  -58.558789  -48.038005  -24.788005
# ..          ...         ...         ...         ...         ...         ...
# 240   22.303371   12.889888   24.730337  185.253933  275.860674  331.660674
# 241  -38.991011  -32.613483  -44.074157  -68.164045 -126.033708 -116.307865
# 242    3.355056 -156.793258  -40.067416  439.424719  566.004494  439.305618
# 243   17.858427  -17.132584  -18.894382  221.357303  334.110112  192.833708
# 244  -61.469663  -79.867416  -70.134831  111.586517  201.249438  187.638202
#
#      ...        CARI2       MCARI       MCARI1    MCARI2         BSI  \
# 0    ...  -548.027851  -20.029130    72.342399  0.025427 -659.073128
# 1    ...   130.459041    1.108586   136.933967  0.001378  713.945652
# 2    ...  -418.199776  -22.605052     5.585273  0.013851 -529.263323
# 3    ...  1022.645456   94.847357   269.156010  0.004282  762.990353
# 4    ...  -221.338162   -3.617405    25.613230  0.007306 -149.665518
# ..   ...          ...         ...          ...       ...         ...
# 240  ...    43.451352   16.912501   473.714966  0.028943  652.173685
# 241  ...  -141.137525  -14.042482  -130.468854 -0.004118 -347.667212
# 242  ... -1082.554975  226.937871  1108.213753  0.099982  -47.336062
# 243  ...  -263.232279   10.156521   356.937438  0.020709   70.299049
# 244  ...  -329.348237   34.835943   413.908584  0.027112 -116.347766
#
#           GLI  ALTERATION         SDI    manure_dates    y
# 0    0.010930   -0.022357 -122.072447  ['2022-04-26']  0.0
# 1   -0.006979   -0.006437   79.198337  ['2022-04-26']  0.0
# 2    0.003935   -0.033256  -77.785036  ['2022-04-26']  0.0
# 3    0.007267    0.043793  208.262470  ['2022-04-26']  0.0
# 4   -0.007368   -0.013217   26.312352  ['2022-04-26']  0.0
# ..        ...         ...         ...             ...  ...
# 240  0.001081    0.035859  188.905618  ['2022-02-24']  0.0
# 241 -0.000851   -0.007368  -13.231461  ['2022-02-24']  0.0
# 242  0.034186    0.050525  718.811236  ['2022-02-24']  0.0
# 243  0.000412    0.004214  300.561798  ['2022-02-24']  0.0
# 244  0.005392    0.008610  312.519101  ['2022-02-24']  0.0
#
# [245 rows x 65 columns]

# %% [markdown]
# ## **Test the best obtained model, on new unseen data**
#
# The primary objective is to conduct a comprehensive test to evaluate the generalization capability of the best obtained model, specifically for crops located in Italy.
#
# This will help to determine the model's ability to generalize and adapt to different crops and environmental conditions, which is a crucial step in this research as it will enable to identify potential shortcomings.
#
# ### Load the model and the feature scaler
#
# In the previous stage, the best model configuration was stored in memory.
# Therefore, there is the need to retrieve the stored model and scaler (**if used**), to ensure that the indexes are transformed correctly and the model can make accurate predictions.
#
# This is an important step, as it will enable us to reuse the best model configuration and avoid the need to retrain the model from scratch, saving us time and resources.

# %%
model = pickle.load(open('../3-ml-models/saved-config/model.pkl', 'rb'))
scaler = pickle.load(open('../3-ml-models/saved-config/scaler.pkl', 'rb'))

# %% [markdown]
# ### Select the useful indexes, and the column to be predicted
#
# It is quite obvious that the selected features should be exactly the same as the ones used by the best model for making predictions.

# %%
X = s2_df_mod[['EOMI3', 'SCI', 'EOMI1', 'SDI']]
y = s2_df_mod.iloc[:, -1]

# %% [markdown]
# ### Show performances
#
# #### Confusion matrix
# A confusion matrix is a comprehensive way to gain more insight about a [classifier's performance](https://www.v7labs.com/blog/confusion-matrix-guide). <br>
# In this case, since our classes are just two, the confusion matrix is binary. A binary confusion matrix is a specific table layout that allows the visualization of the performance of a binary classification algorithm, which is a supervised learning algorithm that classifies the data into two classes.
#
# It is a $[2,2]$ matrix that summarizes the performance of the algorithm by counting the number of true positives (TP), false positives (FP), true negatives (TN), and false negatives (FN). The four outcomes can be formulated in a $[2,2]$ confusion matrix, where the rows represent the actual class and the columns represent the predicted class.
#
# The displacement of TP, TN, FN and FP in the later on printed binary confusion matrix ([sklearn.metrics.confusion_matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)) is the following one:
# $$\begin{bmatrix}
# TN & FP\\
# FN & TP
# \end{bmatrix}$$
#
# The confusion matrix allows the calculation of accuracy, precision, recall, or F1-score. Furthermore, it can also be used to calculate the sensitivity, specificity, and positive and negative predictive values of the algorithm. All of them are useful metrics in order to evaluate the goodness of the considered model.

# %%
y_pred = model.predict(scaler.transform(X) if scaler != None else X)

# %%
# Show confusion matrix
sns.heatmap(confusion_matrix(y, y_pred),
           annot=True,
           fmt='d',
           cbar=False,
           xticklabels=['Not manured', 'Manured'], yticklabels=['Not manured', 'Manured'],
           annot_kws={
                'fontsize': 14
}).set(xlabel='Predicted class', ylabel='Actual class');

# %% [markdown]
# #### Mean accuracy, precision, recall and f1-score
#
# The numeric value under each performance metric represents the weighted average of the metric for the two classes: 0 (not manured) and 1 (manured). That's why using the term *"mean"* before the metric's name. <br>
# Read the [sklearn.metrics documentation](https://scikit-learn.org/stable/modules/model_evaluation.html) if needed.

# %%
# Create a DataFrame containing performance metrics results
pd.DataFrame.from_dict({
    'Mean Accuracy': [round(accuracy_score(y, y_pred), 2)],
    'Mean Precision': [round(precision_score(y, y_pred, average='weighted', zero_division=0), 2)],
    'Mean Recall': [round(recall_score(y, y_pred, average='weighted', zero_division=0), 2)],
    'Mean F1': [round(f1_score(y, y_pred, average='weighted', zero_division=0), 2)]
})
# Out:
#    Mean Accuracy  Mean Precision  Mean Recall  Mean F1
# 0           0.83            0.87         0.83     0.85

# %% [markdown]
# ### Investigation: why errors?
#
# The objective of this investigation is to understand why (and where) the model is making errors in this generalization classification task, with visual tools.

# %%
# Append to the modified DataFrame the prediction column
s2_df_mod2 = pd.concat([s2_df_mod, pd.DataFrame(y_pred).rename(columns={0:'y_pred'})], axis=1)

# %% [markdown]
# #### False negatives

# %%
fn_df = s2_df_mod2[(s2_df_mod2['y']==1) & (s2_df_mod2['y_pred']==0)][['crop_field_name', 'consequent_s2_acquisitions', 'EOMI3', 'SCI', 'EOMI1', 'SDI', 'y', 'y_pred']].set_index('crop_field_name')
fn_df
# Out:
#                 consequent_s2_acquisitions     EOMI3       SCI     EOMI1  \
# crop_field_name
# P-BIPR1           [2022-04-19, 2022-05-01] -0.077942 -0.046141 -0.039643
# P-BIPR2           [2022-04-19, 2022-05-01] -0.109828 -0.091455 -0.090040
# P-BIPR3           [2022-04-19, 2022-05-01] -0.088643 -0.068173 -0.063710
# P-BIPR4           [2022-04-19, 2022-05-01] -0.060981 -0.044708 -0.043019
# P-BIPR6           [2022-04-19, 2022-05-01] -0.039001 -0.002860  0.000308
# P-BIPR8           [2022-04-19, 2022-05-01]  0.009251  0.019916  0.011082
# P-BIPR9           [2022-04-19, 2022-05-01]  0.017511  0.018092  0.039135
# P-PVPR1           [2022-05-01, 2022-05-11] -0.008353 -0.012684 -0.012970
# P-PVPR2           [2022-05-01, 2022-05-11] -0.015671 -0.019516 -0.019485
# P-PVPR3           [2022-05-01, 2022-05-11] -0.023780 -0.028246 -0.034043
# P-PVPR4           [2022-05-01, 2022-05-11] -0.009247 -0.014891 -0.018377
# P-PVPR5           [2022-05-01, 2022-05-11] -0.019318 -0.025819 -0.029030
# P-VAPR1           [2022-03-22, 2022-04-16]  0.044968  0.025541  0.019685
# P-VAPR2           [2022-02-23, 2022-02-25] -0.012166 -0.011576 -0.013759
#
#                         SDI    y  y_pred
# crop_field_name
# P-BIPR1           79.374109  1.0     0.0
# P-BIPR2           12.193531  1.0     0.0
# P-BIPR3         -175.255623  1.0     0.0
# P-BIPR4         -221.702041  1.0     0.0
# P-BIPR6          -54.983283  1.0     0.0
# P-BIPR8          -55.996052  1.0     0.0
# P-BIPR9          -95.329137  1.0     0.0
# P-PVPR1          189.573953  1.0     0.0
# P-PVPR2          265.527778  1.0     0.0
# P-PVPR3          574.912020  1.0     0.0
# P-PVPR4          329.013072  1.0     0.0
# P-PVPR5          509.003989  1.0     0.0
# P-VAPR1         -531.916667  1.0     0.0
# P-VAPR2           13.179775  1.0     0.0

# %% [markdown]
# #### False positives

# %%
fp_df = s2_df_mod2[(s2_df_mod2['y']==0) & (s2_df_mod2['y_pred']==1)][['crop_field_name', 'consequent_s2_acquisitions', 'EOMI3', 'SCI', 'EOMI1', 'SDI', 'y', 'y_pred']].set_index('crop_field_name')
fp_df
# Out:
#                 consequent_s2_acquisitions     EOMI3       SCI     EOMI1  \
# crop_field_name
# P-BIPR1           [2022-03-25, 2022-04-09]  0.102459  0.145668  0.123075
# P-BIPR2           [2022-03-25, 2022-04-09]  0.092287  0.118744  0.145040
# P-BIPR3           [2022-03-25, 2022-04-09]  0.124715  0.186651  0.151713
# P-BIPR4           [2022-03-25, 2022-04-09]  0.064266  0.014963  0.239716
# P-BIPR5           [2022-05-11, 2022-05-14]  0.129792  0.167246  0.137542
# P-BIPR6           [2022-03-25, 2022-04-09]  0.081492  0.139047  0.141081
# P-BIPR7           [2022-03-25, 2022-04-09]  0.092928  0.060036  0.172906
# P-BIPR7           [2022-05-11, 2022-05-14]  0.196881  0.225342  0.206106
# P-PVPE            [2022-02-20, 2022-02-25]  0.171095  0.061607  0.044393
# P-PVPR1           [2022-03-27, 2022-04-11]  0.128968  0.096381  0.084368
# P-PVPR1           [2022-04-11, 2022-04-16]  0.097979  0.102650  0.095143
# P-PVPR2           [2022-03-07, 2022-03-22]  0.072876  0.124697  0.121552
# P-PVPR2           [2022-03-22, 2022-03-27] -0.241446 -0.218551 -0.214116
# P-PVPR2           [2022-03-27, 2022-04-11]  0.153505  0.127749  0.123646
# P-PVPR2           [2022-04-11, 2022-04-16]  0.099140  0.104360  0.098209
# P-PVPR3           [2022-02-20, 2022-02-25]  0.145597  0.082002  0.066560
# P-PVPR3           [2022-03-22, 2022-03-27] -0.252626 -0.235683 -0.219179
# P-PVPR3           [2022-03-27, 2022-04-11]  0.167866  0.144295  0.129329
# P-PVPR3           [2022-04-11, 2022-04-16]  0.095032  0.100604  0.095315
# P-PVPR4           [2022-02-20, 2022-02-25]  0.141992  0.076167  0.066410
# P-PVPR4           [2022-03-22, 2022-03-27] -0.252015 -0.225502 -0.223679
# P-PVPR4           [2022-03-27, 2022-04-11]  0.168135  0.139078  0.134649
# P-PVPR4           [2022-04-11, 2022-04-16]  0.093962  0.099247  0.093579
# P-PVPR5           [2022-02-20, 2022-02-25]  0.143779  0.090209  0.080265
# P-PVPR5           [2022-03-22, 2022-03-27] -0.246179 -0.217792 -0.219676
# P-PVPR5           [2022-03-27, 2022-04-11]  0.163741  0.130349  0.134368
# P-PVPR7           [2022-05-01, 2022-05-11]  0.175071  0.197333  0.185550
#
#                          SDI    y  y_pred
# crop_field_name
# P-BIPR1         -1626.396081  0.0     1.0
# P-BIPR2         -1286.113998  0.0     1.0
# P-BIPR3         -2119.004325  0.0     1.0
# P-BIPR4          -132.157143  0.0     1.0
# P-BIPR5          -214.162431  0.0     1.0
# P-BIPR6         -1737.724924  0.0     1.0
# P-BIPR7         -1004.625488  0.0     1.0
# P-BIPR7          -682.871582  0.0     1.0
# P-PVPE          -1202.978863  0.0     1.0
# P-PVPR1          -589.287442  0.0     1.0
# P-PVPR1         -1042.688372  0.0     1.0
# P-PVPR2         -1025.011574  0.0     1.0
# P-PVPR2          1575.243056  0.0     1.0
# P-PVPR2          -846.513889  0.0     1.0
# P-PVPR2         -1089.187500  0.0     1.0
# P-PVPR3          -612.780669  0.0     1.0
# P-PVPR3          1793.488228  0.0     1.0
# P-PVPR3         -1089.073110  0.0     1.0
# P-PVPR3         -1009.767038  0.0     1.0
# P-PVPR4          -539.739496  0.0     1.0
# P-PVPR4          1701.020542  0.0     1.0
# P-PVPR4         -1026.585434  0.0     1.0
# P-PVPR4         -1042.712418  0.0     1.0
# P-PVPR5          -613.084441  0.0     1.0
# P-PVPR5          1587.603059  0.0     1.0
# P-PVPR5          -945.254654  0.0     1.0
# P-PVPR7         -1939.198873  0.0     1.0

# %% [markdown]
# #### Misclassification errors per crop field
# This graph allows to understand which are the crops that have confused the most the obtained classifier.

# %%
# Group the DataFrame by crop field and calculate the confusion matrix for each group
reports = s2_df_mod2.groupby('crop_field_name').apply(lambda x: confusion_matrix(x['y'], x['y_pred']))

# Extract the false positives and false negatives for each group
fps = [cm.sum(axis=0)[1] - np.diag(cm)[1] for cm in reports]
fns = [cm.sum(axis=1)[1] - np.diag(cm)[1] for cm in reports]

# Create a bar plot of the false positives and false negatives per crop field
plt.figure(figsize=(9,5))
plt.bar(np.arange(len(fps)), fps, label='False Positives')
plt.bar(np.arange(len(fns)), fns, bottom=fps, label='False Negatives')
plt.xticks(np.arange(len(fps)), reports.index)
plt.xlabel('Crop field')
plt.ylabel('Number of errors')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### Trends
#
# By visually examining the trends of the indexes shown later on (and/or referring to the two tables above for false positives and false negatives), it is easy to understand where and why the model is making misclassification errors. <br>
# **Possible reason** for:
# * *false positives*: there are times when indexes change significantly in value even when manure have not been applied
# * *false negatives*: even if manure have been applied the indexes have not been impacted as expected...in few cases the effect of manure on indexes is noticable two acquisitions right after manure application
#
# One interesting result, shows that there is **homogeneity of spectral response to the manure application within crops** (manured) **located in the same country** (trained a model on the Italian crops used in this notebook, then tested its generalization capability on other crops, still located in Italy, and the performance metrics were better).
#
# **Observations**: Shown features values are not the plain original ones, but the scaled between $[-1, 1]$. <br>
# The vertical dashed lines have been added in order to highlight the acquisitions right before and after (or same day) manure application, which is our Region of Interest (namely `RoI`).

# %%
# Sentinel-2
s2_df_norm= utils.get_normalized_df(s2_df, method="min-max")
utils.display_features_trends(s2_df_norm, (0, len(s2_df_norm.crop_field_name.unique())), ['EOMI3', 'SCI', 'EOMI1', 'SDI'], (0, 4), 2)
